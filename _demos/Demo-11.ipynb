# %% [markdown]
# # Demo 11 - Regular Expressions and Web Scraping
#
# In this notebook we look at the basics of the `requests` library, how to use regular expressions in Python, and grabbing information from the web using Beautiful Soup!

# %%
# clone the course repository, change to right directory, and import libraries.
# %cd /content
# !git clone https://github.com/nmattei/cmps3160.git
# %cd /content/cmps3160/_demos
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
plt.style.use('fivethirtyeight')
# Make the fonts a little bigger in our graphs.
font = {'size'   : 20}
plt.rc('font', **font)
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams['pdf.fonttype'] = 42
# Out:
# /content
# Cloning into 'cmps3160'...
# remote: Enumerating objects: 1647, done.
# remote: Counting objects: 100% (537/537), done.
# remote: Compressing objects: 100% (229/229), done.
# remote: Total 1647 (delta 319), reused 445 (delta 261), pack-reused 1110
# Receiving objects: 100% (1647/1647), 45.27 MiB | 22.54 MiB/s, done.
# Resolving deltas: 100% (920/920), done.
# /content/cmps3160/_demos

# %%
# Note you may have to install requests!  pip3 install requests
import requests

# %% [markdown]
# ## Simple Webpage Call with Requests Library
#
# It may be good to look at the reference documentation for the [requests library](https://2.python-requests.org/en/master/user/quickstart/).
#
# First, let's have a look at the [PolitWoops](https://projects.propublica.org/politwoops/).
#
# Or even [Prof. Culotta's Website](https://cs.tulane.edu/~aculotta/)

# %%
r = requests.get('https://cs.tulane.edu/~aculotta/', timeout=10)
r.status_code
# Out:
# 200

# %%
r.headers['content-type']
# Out:
# 'text/html; charset=UTF-8'

# %%
r.url
# Out:
# 'https://cs.tulane.edu/~aculotta/'

# %%
# Note that this is the same as if we just got to the page!
r.content[:5000]
# Out:
# b'<html>\n\t<head>\n\t\t<link rel="stylesheet" href="style.css">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1">\n\t</head>\n\t<body>\n\t\t<div class="main">\n\t\t\taron culotta  &nbsp;&nbsp;&nbsp;&nbsp;  &nbsp; <br>associate professor of computer science<br>tulane university<br>\n\t\t\t<script type="text/javascript" language="javascript"> // Email obfuscator script 2.1 by Tim Williams, University of Arizona\n\t\t\t{ coded = "LzVZhppL@pVZLJW.WlV"\n  \t\t\t\tkey = "fID9HXVvy5dwPqtn0FjROcgms4kr1l7xKpJeaSQ3zoA8NUEYZubiMBWLTGC6h2"\n\t  \t\t\tshift=coded.length\n\t\t\t\t  link=""\n\t\t\t\t  for (i=0; i<coded.length; i++) {\n\t\t\t\t    if (key.indexOf(coded.charAt(i))==-1) {\n\t\t\t\t      ltr = coded.charAt(i)\n\t\t\t\t      link += (ltr)\n\t\t\t\t    }\n\t\t\t\t    else { \n\t\t\t\t      ltr = (key.indexOf(coded.charAt(i))-shift+key.length) % key.length\n\t\t\t\t      link += (key.charAt(ltr))\n\t\t\t\t    }\n\t\t\t\t  }\n\t\t\t\tdocument.write(link)\n\t\t\t\t}\n\t\t\t\t//-->\n\t\t\t</script>\n\t\t\t<noscript>Sorry, you need Javascript on to email me.</noscript>\n\t\t\t<br>\n\t\t\t<font size=+2>\n\t\t\t<a href="cv.pdf">cv</a> &nbsp; <a href="http://scholar.google.com/citations?user=481oUzkAAAAJ">scholar</a> &nbsp; <a href="#teaching">teaching</a> &nbsp; <a href="#funding">funding</a> &nbsp; <a href="#awards">awards</a> &nbsp; <a href="#publications">pubs</a></font>\n\t\t\t<br><br><br>\n\n\n\t\t\tI investigate computational methods to discover socially-beneficial knowledge from text and social networks.\n\t\t\tExamples include <a href="http://cs.tulane.edu/~aculotta/pubs/culotta13lightweight.pdf">tracking</a> <a href="http://cs.tulane.edu/~aculotta/pubs/culotta10detecting.pdf">diseases</a>, measuring effectiveness of <a href="http://cs.tulane.edu/~aculotta/pubs/culotta16towards.pdf">public health</a> campaigns, <a href="http://cs.tulane.edu/~aculotta/pubs/ashktorab14tweedr.pdf">informing</a> crisis <a href="http://cs.tulane.edu/~aculotta/pubs/mandel12demo.pdf">response</a>, <a href="http://cs.tulane.edu/~aculotta/pubs/liu2018forecasting.pdf">preventing online harassment</a>, <a href="http://cs.tulane.edu/~aculotta/pubs/wang17words.pdf">detecting deceptive marketing</a>, and <a href="http://cs.tulane.edu/~aculotta/pubs/bhat17identifying.pdf">identifying unsafe products</a>.\n\t\t    </p>\n\t\t\t\n\t\t\t\n\t\t\t<p>\n\t\t\tThe methods rely on machine learning, natural language processing, and social network analysis. Areas of technical contribution include <a href="http://cs.tulane.edu/~aculotta/pubs/landeiro19discovering.pdf">domain adaptation</a>, <a href="http://cs.tulane.edu/~aculotta/pubs/ehsan17training.pdf">learning from label proportions</a>, and <a href="http://cs.tulane.edu/~aculotta/pubs/wang19when.pdf">causal inference</a>.\n\t\t\t <!-- See our <a href="http://tapilab.github.io/">lab page</a> for more. -->\n\t\t\t</p>\n\t\t\t\n\n \t\t\t<p>\n\t\t\tI also lead the <a href="https://tulanecs.github.io/tuceai/">Tulane Center for Community-Engaged Artificial Intelligence</a> and the <a href="https://ai.tulane.edu/">Jurist Center for Artificial Intelligence</a>.\n\t\t\t</p>\n\n\t\t\t<p>\n\t\t\t<br>\n\t\t\tAre you a student interested in a <a href="https://goo.gl/forms/XCJAwpzva0DE7Pol1">phd</a> or <a href="https://goo.gl/forms/3vEGOWcMcS79kALj1">independent study</a>?\n\t\t\t</p>\n\n\t\t\t<br><br>\n\n\t\t\t<a name="teaching"><span class=\'bold\'>teaching</span></a>\n\t\t\t<br><br>\n\t\t\t<table class="teaching" border=0>\n\t\t\t\t<tr>\n\t\t\t\t\t<td>&nbsp;&nbsp;&nbsp;&nbsp;</td>\n\t\t\t\t\t<td>tulane</td>\n\t\t\t\t\t<td>&nbsp;&nbsp;&nbsp;&nbsp;</td>\n\t\t\t\t\t<td><a href="https://github.com/tulane-cmps6730/main">natural language processing</a>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>\n\t\t\t\t\t<td><a href="https://github.com/tulane-cmps2200/slides/tree/2020-fall">intro to algorithms</a></td>\n\t\t\t\t</tr>\n\t\t\t\t<tr>\n\t\t\t\t\t<td>&nbsp;&nbsp;&nbsp;&nbsp;</td>\n\t\t\t\t\t<td>illinois tech</t ...

# %% [markdown]
# **Point:** A really great resource is to check out this page [What happens when you type google.com into the address bar](https://github.com/alex/what-happens-when) which goes through the whole stack!

# %%
r = requests.get('https://projects.propublica.org/politwoops/', timeout=10)
r.status_code
# Out:
# 200

# %%
r.headers['content-type']
# Out:
# 'text/html; charset=utf-8'

# %%
r.url
# Out:
# 'https://projects.propublica.org/politwoops/'

# %%
r.content[:5000]

# %% [markdown]
# ## Looking at HTTP Requests
#
# We'll try to get some data from Google.  Note that this is kind of against the TOS and we **should not do it this way in general -- Google has very [specific rules on their site](https://developers.google.com/custom-search/v1/).**

# %%
params = {'q':'Tulane University'}
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:101.0) Gecko/20100101 Firefox/101.0'}
r = requests.get('http://www.google.com/search', params = params, headers=headers, timeout=10)
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://www.google.com/search?q=Tulane+University&gws_rd=ssl'

# %%
r.headers['content-type']
# Out:
# 'text/html; charset=UTF-8'

# %%
r.text[:5000]
# Out:
# '<!doctype html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="zh-TW"><head><meta charset="UTF-8"><meta content="origin" name="referrer"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Tulane University - Google 搜尋</title><script nonce="kNTI83Xap_yCMqM4r4t89Q">(function(){var b=window.addEventListener;window.addEventListener=function(a,c,d){"unload"!==a&&b(a,c,d)};}).call(this);(function(){var _g={kEI:\'0l7OZIaDK5ng2roP1Om26Ag\',kEXPI:\'31\',kBL:\'XHw5\',kOPI:89978449};(function(){var a;(null==(a=window.google)?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){google.sn=\'web\';google.kHL=\'zh-TW\';})();(function(){\nvar h=this||self;function l(){return void 0!==window.google&&void 0!==window.google.kOPI&&0!==window.google.kOPI?window.google.kOPI:null};var m,n=[];function p(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||m}function q(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}function r(a){/^http:/i.test(a)&&"https:"===window.location.protocol&&(google.ml&&google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a}\nfunction t(a,b,c,d,k){var e="";-1===b.search("&ei=")&&(e="&ei="+p(d),-1===b.search("&lei=")&&(d=q(d))&&(e+="&lei="+d));d="";var g=-1===b.search("&cshid=")&&"slh"!==a,f=[];f.push(["zx",Date.now().toString()]);h._cshid&&g&&f.push(["cshid",h._cshid]);c=c();null!=c&&f.push(["opi",c.toString()]);for(c=0;c<f.length;c++){if(0===c||0<c)d+="&";d+=f[c][0]+"="+f[c][1]}return"/"+(k||"gen_204")+"?atyp=i&ct="+String(a)+"&cad="+(b+e+d)};m=google.kEI;google.getEI=p;google.getLEI=q;google.ml=function(){return null};google.log=function(a,b,c,d,k,e){e=void 0===e?l:e;c||(c=t(a,b,e,d,k));if(c=r(c)){a=new Image;var g=n.length;n[g]=a;a.onerror=a.onload=a.onabort=function(){delete n[g]};a.src=c}};google.logUrl=function(a,b){b=void 0===b?l:b;return t("",a,b)};}).call(this);(function(){google.y={};google.sy=[];google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.sx=function(a){google.sy.push(a)};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};google.bx=!1;google.lx=function(){};}).call(this);google.f={};(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){google.hs={h:true,nhs:false,sie:false};})();(function(){google.c={bfrt:false,bfrte:true,bofr:true,btfi:false,c4t:false,cap:2000,fla:false,fli:false,frt:false,frvt:true,gl:false,irsf:false,lhc:false,llt:false,mais:false,pbph:false,raf:false,sxs:false,taf:true,timl:false,upb:false,vis:true,wh0:false,whu:false};})();(function(){\nvar f=this||self;var g=window.performance;var h=google.c.gl,k=google.c.sxs;function l(a,b,d,c){a.addEventListener?a.addEventListener(b,d,c||!1):a.attachEvent&&a.attachEvent("on"+b,d)}function m(a,b,d,c){"addEventListener"in a?a.removeEventListener(b,d,c||!1):a.attachEvent&&a.detachEvent("on"+b,d)};google.c.iim=google.c.iim||{};function n(a){a&&f.google.aft(a.target)}var p;function q(){m(document.documentElement,"load",p,!0);m(document.documentElement,"error",p,!0)};google.timers={};google.startTick=function(a){google.timers[a]={t:{start:Date.now()},e:{},m:{}}};google.tick=function(a,b,d){google.timers[a]||google.startTick(a);d=void 0!==d?d:Date.now();b instanceof Array||(b=[b]);for(var c=0,e;e=b[c++];)google.timers[a].t[e]=d};google.c ...

# %%
# This is a bit messy, let's use Beautiful Soup (we'll see this more later) to get just the text information.
from bs4 import BeautifulSoup
soup = BeautifulSoup( r.content )
print(soup.prettify()[:5000])
print("\n\nText only: \n\n")
print(soup.get_text().split()[:50])
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="zh-TW">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <title>
#    Tulane University - Google 搜尋
#   </title>
#   <script nonce="kNTI83Xap_yCMqM4r4t89Q">
#    (function(){var b=window.addEventListener;window.addEventListener=function(a,c,d){"unload"!==a&&b(a,c,d)};}).call(this);(function(){var _g={kEI:'0l7OZIaDK5ng2roP1Om26Ag',kEXPI:'31',kBL:'XHw5',kOPI:89978449};(function(){var a;(null==(a=window.google)?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){google.sn='web';google.kHL='zh-TW';})();(function(){
# var h=this||self;function l(){return void 0!==window.google&&void 0!==window.google.kOPI&&0!==window.google.kOPI?window.google.kOPI:null};var m,n=[];function p(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||m}function q(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}function r(a){/^http:/i.test(a)&&"https:"===window.location.protocol&&(google.ml&&google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a}
# function t(a,b,c,d,k){var e="";-1===b.search("&ei=")&&(e="&ei="+p(d),-1===b.search("&lei=")&&(d=q(d))&&(e+="&lei="+d));d="";var g=-1===b.search("&cshid=")&&"slh"!==a,f=[];f.push(["zx",Date.now().toString()]);h._cshid&&g&&f.push(["cshid",h._cshid]);c=c();null!=c&&f.push(["opi",c.toString()]);for(c=0;c<f.length;c++){if(0===c||0<c)d+="&";d+=f[c][0]+"="+f[c][1]}return"/"+(k||"gen_204")+"?atyp=i&ct="+String(a)+"&cad="+(b+e+d)};m=google.kEI;google.getEI=p;google.getLEI=q;google.ml=function(){return null};google.log=function(a,b,c,d,k,e){e=void 0===e?l:e;c||(c=t(a,b,e,d,k));if(c=r(c)){a=new Image;var g=n.length;n[g]=a;a.onerror=a.onload=a.onabort=function(){delete n[g]};a.src=c}};google.logUrl=function(a,b){b=void 0===b?l:b;return t("",a,b)};}).call(this);(function(){google.y={};google.sy=[];google.x=function(a,b){if(a)var c=a.id;else{do c=Math.random();while(google.y[c])}google.y[c]=[a,b];return!1};google.sx=function(a){google.sy.push(a)};google.lm=[];google.plm=function(a){google.lm.push.apply(google.lm,a)};google.lq=[];google.load=function(a,b,c){google.lq.push([[a],b,c])};google.loadAll=function(a,b){google.lq.push([a,b])};google.bx=!1;google.lx=function(){};}).call(this);google.f={};(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){google.hs={h:true,nhs:false,sie:false};})();(function(){google.c={bfrt:false,bfrte:true,bofr:true,btfi:false,c4t:false,cap:2000,fla:false,fli:false,frt:false,frvt:true,gl:false,irsf:false,lhc:false,llt:false,mais:false,pbph:false,raf:false,sxs:false,taf:true,timl:false,upb:false,vis:true,wh0:false,whu:false};})();(function(){
# var f=this||self;var g=window.performance;var h=google.c.gl,k=google.c.sxs;function l(a,b,d,c){a.addEventListener?a.addEventListener(b,d,c||!1):a.attachEvent&&a.attachEvent("on"+b,d)}function m(a,b,d,c){"addEventListener"in a?a.removeEventListener(b,d,c||!1):a.attachEvent&&a.detachEvent("on"+b,d)};google.c.iim=google.c.iim||{};function n(a){a&&f.google.aft(a.target)}var p;function q(){m(document.documentElement,"load",p,!0);m(document.documentElement,"error",p,!0)};google.timers={};google.startTick=function(a){google.timers[a]={t:{start:Date.now()},e:{},m:{}}};google.tick=function(a,b,d){google.timers[a]||google.startTick(a);d=void 0!==d?d:Date.now();b instanceof Array||(b=[b]);for(var c=0,e;e=b[c++];)google.timers[a].t[e]=d};google.c.e=function(a,b,d){google.timers[a].e[b]=d};google.c.b=function(a,b){b=google.timers[b||"load"].m;b[a]&&google.ml(Error("a"),!1,{m:a});b[a]=!0};google.c.u=function(a,b){var d=google.timers[b||"load"],c=d.m;if(c[a]){c[a]=!1;for(a in c)if(c[a])return;google.csiReport(d,k&&"load2"===b?"all2":"all")}else{b="";for(var e in c)b+=e+":"+c[e]+";";google.ml(Error("b"),!1,{m:a,b:!1===c[a],s:b})}};google.rll=function(a,b,d){function c(e){d(e);m(a,"load",c);m(a,"error",c)}l(a,"load",c);b&&l(a,"error",c)};f.google.aft=function(a){a.setAttribute("data-iml",String(Date.now()))};google.startTick("load");var r=google.timers.load;if(!google.stvsc)a:{var t=r.t;if(g){var u=g.timing;if(u){var v=u.navigationStart,w=u.responseStart;if(w>v&&w<=t.start){t.start=w;r.wsrt=w-v;break a}}g.now&&(r.wsrt=Math.floor(g.now()))}}google.c.b("pr","load");google.c.b("xe","load");var x;if(null==(x=google.stvsc)?0:x.start)google.timers.load.t.start=google.stvsc.start;function y(a){if("hidden"===document.visib
#
#
# Text only:
#
#
# ['Tulane', 'University', '-', 'Google', '搜尋如果系統沒有在數秒鐘後將您重新導向，請按一下這裡。無障礙連結跳至主內容無障礙說明無障礙工具意見回饋', '按下', '/', '鍵即可跳至搜尋框Tulane', 'University', '顯示更多刪除刪除回報不適當的預測查詢字串', '篩選器和主題新聞圖片地圖排名約有', '31,100,000', '項結果', '(搜尋時間：0.60', '秒)', '提示：', '限制搜尋繁體中文的結果。瞭解詳情如何依語言過濾結果搜尋結果Home', '|', 'tulanetulane.eduhttps://tulane.edutulane.eduhttps://tulane.edu', '·', '翻譯這個網頁Tulane', 'University', 'is', 'a', 'comprehensive', 'research', 'university', 'in', 'New', 'Orleans,', 'Louisiana.', 'Tulanians', 'see', 'challenges', 'as', 'opportunities,', 'and', 'strive', 'to', 'improve', 'the', '...\u200eMajors', '&', 'Minors', '·', '\u200eGraduate', 'Education', '·', '\u200eUndergraduate', 'Admission']

# %%
params = {'q':'Tulane University'}
r = requests.get('https://duckduckgo.com/', params = params, timeout=10)
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://duckduckgo.com/static/duckduckgo/418.html?bno=2162&is_tor=0&is_ar=0'

# %%
r.headers['content-type']
# Out:
# 'text/html; charset=UTF-8'

# %%
r.text
# Out:
# '<!DOCTYPE html>\n<!--[if IEMobile 7 ]> <html lang="en-US" class="no-js iem7"> <![endif]-->\n<!--[if lt IE 7]> <html class="ie6 lt-ie10 lt-ie9 lt-ie8 lt-ie7 no-js" lang="en-US"> <![endif]-->\n<!--[if IE 7]>    <html class="ie7 lt-ie10 lt-ie9 lt-ie8 no-js" lang="en-US"> <![endif]-->\n<!--[if IE 8]>    <html class="ie8 lt-ie10 lt-ie9 no-js" lang="en-US"> <![endif]-->\n<!--[if IE 9]>    <html class="ie9 lt-ie10 no-js" lang="en-US"> <![endif]-->\n<!--[if (gte IE 9)|(gt IEMobile 7)|!(IEMobile)|!(IE)]><!--><html class="no-js" lang="en-US" data-ntp-features="tracker-stats-widget:off"><!--<![endif]-->\n\n<head>\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n<meta http-equiv="content-type" content="text/html; charset=UTF-8;charset=utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1, user-scalable=1" />\n<meta name="HandheldFriendly" content="true"/>\n<meta name="darkreader-lock" />\n\n<link rel="canonical" href="https://duckduckgo.com/418.html">\n\n<link rel="stylesheet" href="/s2179.css" type="text/css">\n\n<link rel="stylesheet" href="/o2179.css" type="text/css">\n\n\n\n\n\n\n<meta name="apple-itunes-app" content="app-id=663592361, app-argument=https://duckduckgo.com/?smartbanner=1">\n\n\n<link rel="preload" href="/font/ProximaNova-Reg-webfont.woff2" as="font" type="font/woff2" crossorigin="anonymous"/>\n<link rel="preload" href="/font/ProximaNova-Sbold-webfont.woff2" as="font" type="font/woff2" crossorigin="anonymous"/>\n<link rel="preload" href="/font/ProximaNova-ExtraBold-webfont.woff2" as="font" type="font/woff2" crossorigin="anonymous"/>\n\n<link rel="shortcut icon" href="/favicon.ico" type="image/x-icon"/>\n<link rel="apple-touch-icon" href="/assets/icons/meta/DDG-iOS-icon_60x60.png"/>\n<link rel="apple-touch-icon" sizes="76x76" href="/assets/icons/meta/DDG-iOS-icon_76x76.png"/>\n<link rel="apple-touch-icon" sizes="120x120" href="/assets/icons/meta/DDG-iOS-icon_120x120.png"/>\n<link rel="apple-touch-icon" sizes="152x152" href="/assets/icons/meta/DDG-iOS-icon_152x152.png"/>\n<link rel="image_src" href="/assets/icons/meta/DDG-icon_256x256.png"/>\n<link rel="manifest" href="/manifest.json"/>\n\n<meta name="twitter:card" content="summary">\n<meta name="twitter:site" value="@duckduckgo">\n\n<meta property="og:url" content="https://duckduckgo.com/418.html" />\n<meta property="og:site_name" content="DuckDuckGo" />\n<meta property="og:image" content="https://duckduckgo.com/assets/logo_social-media.png">\n\n\n\t<title>DuckDuckGo</title>\n\n\n</head>\n<body id="pg-418" class="page-418 body--home">\n\t<script>window.didNotLoadScripts=[];function handleScriptError(el) { if (el && el.getAttribute) { window.didNotLoadScripts.push(el.getAttribute(\'src\')); }}</script>\n\n<script type="text/javascript" src="/tl7.js" onerror="handleScriptError(this)"></script>\n<script type="text/javascript" src="/b233.js" onerror="handleScriptError(this)"></script>\n<script type="text/javascript" src="/lib/l133.js" onerror="handleScriptError(this)"></script>\n<script type="text/javascript" src="/locale/en_US/duckduckgo14.js" onerror="handleScriptError(this)"></script>\n<script type="text/javascript" src="/util/u736.js" onerror="handleScriptError(this)"></script>\n\n\n\n<script type="text/javascript" src="/d3239.js" onerror="handleScriptError(this)"></script>\n\n\n<script type="text/javascript" src="/h37.js" onerror="handleScriptError(this)"></script>\n\n\n<script type="text/javascript" src="/ti7.js" onerror="handleScriptError(this)"></script>\n\n\n\n\t<div class="site-wrapper  site-wrapper--home  js-site-wrapper">\n\t\n\t\t\n\t\t\t<div class="header-wrap--home  js-header-wrap">\n\t<div class="header--aside js-header-aside"></div>\n</div>\n\t\t\t<div id="" class="content-wrap--home">\n\t\t\t\t<div id="content_homepage" class="content--home" style="visibility: hidden">\n\t\t\t\t\t<div class="cw--c">\n\t\t\t\t\t\t\t\t<div class="logo-wrap--home">\n\t\t\t<a id="logo_homepage_link" class="logo_homepage" href="/about">\n\t\t\t\t ...

# %% [markdown]
# Well, that's lame because it basically just redirects to google :-)
#
# ## Simple API Call with Requests Library
#
# It may be good to look at the reference documentation for the [requests library](https://2.python-requests.org/en/master/user/quickstart/).
#
# First, let's have a look at the [GitHub API](https://developer.github.com/v3/).

# %%
r = requests.get('https://api.github.com/users/nmattei', timeout=10)
r.status_code
# Out:
# 200

# %%
r.headers['content-type']
# Out:
# 'application/json; charset=utf-8'

# %%
r.url
# Out:
# 'https://api.github.com/users/nmattei'

# %%
r.content
# Out:
# b'{"login":"nmattei","id":1206578,"node_id":"MDQ6VXNlcjEyMDY1Nzg=","avatar_url":"https://avatars.githubusercontent.com/u/1206578?v=4","gravatar_id":"","url":"https://api.github.com/users/nmattei","html_url":"https://github.com/nmattei","followers_url":"https://api.github.com/users/nmattei/followers","following_url":"https://api.github.com/users/nmattei/following{/other_user}","gists_url":"https://api.github.com/users/nmattei/gists{/gist_id}","starred_url":"https://api.github.com/users/nmattei/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/nmattei/subscriptions","organizations_url":"https://api.github.com/users/nmattei/orgs","repos_url":"https://api.github.com/users/nmattei/repos","events_url":"https://api.github.com/users/nmattei/events{/privacy}","received_events_url":"https://api.github.com/users/nmattei/received_events","type":"User","site_admin":false,"name":"Nicholas Mattei","company":"Tulane University","blog":"http://www.nickmattei.net","location":null,"email":null,"hireable":null,"bio":null,"twitter_username":null,"public_repos":15,"public_gists":0,"followers":27,"following":15,"created_at":"2011-11-19T15:38:51Z","updated_at":"2023-07-11T11:15:49Z"}'

# %%
r.json()
# Out:
# {'login': 'nmattei',
#  'id': 1206578,
#  'node_id': 'MDQ6VXNlcjEyMDY1Nzg=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/1206578?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/nmattei',
#  'html_url': 'https://github.com/nmattei',
#  'followers_url': 'https://api.github.com/users/nmattei/followers',
#  'following_url': 'https://api.github.com/users/nmattei/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/nmattei/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/nmattei/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/nmattei/subscriptions',
#  'organizations_url': 'https://api.github.com/users/nmattei/orgs',
#  'repos_url': 'https://api.github.com/users/nmattei/repos',
#  'events_url': 'https://api.github.com/users/nmattei/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/nmattei/received_events',
#  'type': 'User',
#  'site_admin': False,
#  'name': 'Nicholas Mattei',
#  'company': 'Tulane University',
#  'blog': 'http://www.nickmattei.net',
#  'location': None,
#  'email': None,
#  'hireable': None,
#  'bio': None,
#  'twitter_username': None,
#  'public_repos': 15,
#  'public_gists': 0,
#  'followers': 27,
#  'following': 15,
#  'created_at': '2011-11-19T15:38:51Z',
#  'updated_at': '2023-07-11T11:15:49Z'}

# %% [markdown]
# ## More Complicated with Parameters
#
# We'll look for some information from the [Apple ITunes API](https://affiliate.itunes.apple.com/resources/documentation/itunes-store-web-service-search-api/).

# %%
params = {'term' : "the+meters"}
r = requests.get('https://itunes.apple.com/search', params=params, timeout=10)
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://itunes.apple.com/search?term=the%2Bmeters'

# %%
r.json()

# %% [markdown]
# We can do lots of parameters in the payload like [this](https://2.python-requests.org/en/master/user/quickstart/).

# %%
params = {'term' : "the+meters", 'entity' : 'album'}
r = requests.get('https://itunes.apple.com/search', params=params, timeout=10)
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://itunes.apple.com/search?term=the%2Bmeters&entity=album'

# %%
r.json()

# %%
x = r.json()

# %%
type(x['results'][0])
# Out:
# dict

# %% [markdown]
# ## Converting the returned JSON to an object!

# %%
import json

# %%
data = json.loads(r.content)

# %%
data.keys()
data['results']

# %%
type(data['results'])
# Out:
# list

# %%
type(data['results'][1])
# Out:
# dict

# %%
data['results'][1]
# Out:
# {'wrapperType': 'collection',
#  'collectionType': 'Album',
#  'artistId': 7314214,
#  'collectionId': 213532006,
#  'amgArtistId': 4907,
#  'artistName': 'The Meters',
#  'collectionName': 'The Very Best of The Meters',
#  'collectionCensoredName': 'The Very Best of The Meters',
#  'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#  'collectionViewUrl': 'https://music.apple.com/us/album/the-very-best-of-the-meters/213532006?uo=4',
#  'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music/ed/62/d2/mzi.bupngrkr.jpg/60x60bb.jpg',
#  'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music/ed/62/d2/mzi.bupngrkr.jpg/100x100bb.jpg',
#  'collectionPrice': 9.99,
#  'collectionExplicitness': 'notExplicit',
#  'trackCount': 16,
#  'copyright': '℗ 2005 Warner Strategic Marketing',
#  'country': 'USA',
#  'currency': 'USD',
#  'releaseDate': '2005-03-29T08:00:00Z',
#  'primaryGenreName': 'R&B/Soul'}

# %%
data['results'][1].keys()
# Out:
# dict_keys(['wrapperType', 'collectionType', 'artistId', 'collectionId', 'amgArtistId', 'artistName', 'collectionName', 'collectionCensoredName', 'artistViewUrl', 'collectionViewUrl', 'artworkUrl60', 'artworkUrl100', 'collectionPrice', 'collectionExplicitness', 'trackCount', 'copyright', 'country', 'currency', 'releaseDate', 'primaryGenreName'])

# %% [markdown]
# So that works really well to get a dict, but more importantly Pandas will convert this to a DataFrame for us!! More information in the [read_json() function](https://pandas.pydata.org/docs/reference/api/pandas.read_json.html)

# %%
df_t = pd.DataFrame.from_dict(data["results"])
df_t
# Out:
#    wrapperType collectionType    artistId  collectionId  amgArtistId  \
# 0   collection          Album     7314214      59401239       4907.0
# 1   collection          Album     7314214     213532006       4907.0
# 2   collection          Album     7314214      56763785       4907.0
# 3   collection          Album     7314214      59401178       4907.0
# 4   collection          Album     7314214      59401414       4907.0
# 5   collection          Album     7314214     159362708       4907.0
# 6   collection          Album     7314214      80003971       4907.0
# 7   collection          Album     7314214      59401344       4907.0
# 8   collection          Album     7314214     257194137       4907.0
# 9   collection          Album     7314214      80014990       4907.0
# 10  collection          Album     7314214     160973598       4907.0
# 11  collection          Album     7314214     160973024       4907.0
# 12  collection          Album     7314214    1188230324       4907.0
# 13  collection          Album     7314214     160973768       4907.0
# 14  collection          Album     7314214     343757693       4907.0
# 15  collection          Album     7314214    1528751623       4907.0
# 16  collection          Album   646931161    1681081201    3681076.0
# 17  collection          Album  1531462629    1531349775          NaN
# 18  collection          Album     7314214    1504262996       4907.0
# 19  collection          Album   646931161    1605162255    3681076.0
#
#                              artistName  \
# 0                            The Meters
# 1                            The Meters
# 2                            The Meters
# 3                            The Meters
# 4                            The Meters
# 5                            The Meters
# 6                            The Meters
# 7                            The Meters
# 8                            The Meters
# 9                            The Meters
# 10                           The Meters
# 11                           The Meters
# 12                           The Meters
# 13                           The Meters
# 14                           The Meters
# 15                           The Meters
# 16                               Farees
# 17                           The Meters
# 18                           The Meters
# 19  Farees, Leo Nocentelli & The Meters
#
#                                        collectionName  \
# 0                                          The Meters
# 1                         The Very Best of The Meters
# 2             Funkify Your Life: The Meters Anthology
# 3                                        Rejuvenation
# 4                                   Fire On the Bayou
# 5                                       Look-Ka Py Py
# 6                      Rhino Hi-Five: The Meters - EP
# 7                                       Cabbage Alley
# 8                          The Essentials: The Meters
# 9                                            Kickback
# 10                                          Struttin'
# 11                                     New Directions
# 12                                        Cissy Strut
# 13                                          Trick Bag
# 14                                     Live At Rozy's
# 15       Uptown Rulers! Live on the Queen Mary (Live)
# 16  The Melting (feat. Leo Nocentelli & The Meters...
# 17                                     Signs - Single
# 18  Gettin' Funkier All the Time: The Complete Jos...
# 19                               The Melting - Single
#
#                                collectionCensoredName  \
# 0                                          The Meters
# 1                         The Very Best of The Meters
# 2             Funkify Your Life: The Meters Anthology
# 3                                        Rejuvenation
# 4                                   Fire On the Bayou
# 5                                       Look-Ka Py Py
# 6                      Rhino Hi-Five: The Meters - EP
# 7                                       Cabbage Alley
# 8                          The Essentials: The Meters
# 9                                            Kickback
# 10                                          Struttin'
# 11                                     New Directions
# 12                                        Cissy Strut
# 13                                          Trick Bag
# 14                                     Live At Rozy's
# 15       Uptown Rulers! Live on the Queen Mary (Live)
# 16  The Melting (feat. Leo Nocentelli & The Meters...
# 17                                     Signs - Single
# 18  Gettin' Funkier All the Time: The Complete Jos...
# 19                               The Melting - Single
#
#                                         artistViewUrl  \
# 0   https://music.apple.com/us/artist/the-meters/7...
# 1   https://music.apple.com/us/artist/the-meters/7...
# 2   https://music.apple.com/us/artist/the-meters/7...
# 3   https://music.apple.com/us/artist/the-meters/7...
# 4   https://music.apple.com/us/artist/the-meters/7...
# 5   https://music.apple.com/us/artist/the-meters/7...
# 6   https://music.apple.com/us/artist/the-meters/7...
# 7   https://music.apple.com/us/artist/the-meters/7...
# 8   https://music.apple.com/us/artist/the-meters/7...
# 9   https://music.apple.com/us/artist/the-meters/7...
# 10  https://music.apple.com/us/artist/the-meters/7...
# 11  https://music.apple.com/us/artist/the-meters/7...
# 12  https://music.apple.com/us/artist/the-meters/7...
# 13  https://music.apple.com/us/artist/the-meters/7...
# 14  https://music.apple.com/us/artist/the-meters/7...
# 15  https://music.apple.com/us/artist/the-meters/7...
# 16  https://music.apple.com/us/artist/farees/64693...
# 17  https://music.apple.com/us/artist/the-meters/1...
# 18  https://music.apple.com/us/artist/the-meters/7...
# 19  https://music.apple.com/us/artist/farees/64693...
#
#                                     collectionViewUrl  ...  \
# 0   https://music.apple.com/us/album/the-meters/59...  ...
# 1   https://music.apple.com/us/album/the-very-best...  ...
# 2   https://music.apple.com/us/album/funkify-your-...  ...
# 3   https://music.apple.com/us/album/rejuvenation/...  ...
# 4   https://music.apple.com/us/album/fire-on-the-b...  ...
# 5   https://music.apple.com/us/album/look-ka-py-py...  ...
# 6   https://music.apple.com/us/album/rhino-hi-five...  ...
# 7   https://music.apple.com/us/album/cabbage-alley...  ...
# 8   https://music.apple.com/us/album/the-essential...  ...
# 9   https://music.apple.com/us/album/kickback/8001...  ...
# 10  https://music.apple.com/us/album/struttin/1609...  ...
# 11  https://music.apple.com/us/album/new-direction...  ...
# 12  https://music.apple.com/us/album/cissy-strut/1...  ...
# 13  https://music.apple.com/us/album/trick-bag/160...  ...
# 14  https://music.apple.com/us/album/live-at-rozys...  ...
# 15  https://music.apple.com/us/album/uptown-rulers...  ...
# 16  https://music.apple.com/us/album/the-melting-f...  ...
# 17  https://music.apple.com/us/album/signs-single/...  ...
# 18  https://music.apple.com/us/album/gettin-funkie...  ...
# 19  https://music.apple.com/us/album/the-melting-s...  ...
#
#                                         artworkUrl100 collectionPrice  \
# 0   https://is2-ssl.mzstatic.com/image/thumb/Music...            9.99
# 1   https://is1-ssl.mzstatic.com/image/thumb/Music...            9.99
# 2   https://is3-ssl.mzstatic.com/image/thumb/Music...           29.99
# 3   https://is1-ssl.mzstatic.com/image/thumb/Music...            9.99
# 4   https://is5-ssl.mzstatic.com/image/thumb/Music...            9.99
# 5   https://is3-ssl.mzstatic.com/image/thumb/Music...            9.99
# 6   https://is5-ssl.mzstatic.com/image/thumb/Music...            3.99
# 7   https://is5-ssl.mzstatic.com/image/thumb/Music...            9.99
# 8   https://is4-ssl.mzstatic.com/image/thumb/Music...            9.99
# 9   https://is3-ssl.mzstatic.com/image/thumb/Music...            9.99
# 10  https://is1-ssl.mzstatic.com/image/thumb/Music...            9.99
# 11  https://is1-ssl.mzstatic.com/image/thumb/Music...            9.99
# 12  https://is5-ssl.mzstatic.com/image/thumb/Music...           10.99
# 13  https://is1-ssl.mzstatic.com/image/thumb/Music...            9.99
# 14  https://is5-ssl.mzstatic.com/image/thumb/Music...            9.99
# 15  https://is5-ssl.mzstatic.com/image/thumb/Music...            7.99
# 16  https://is5-ssl.mzstatic.com/image/thumb/Music...            1.29
# 17  https://is1-ssl.mzstatic.com/image/thumb/Music...            0.99
# 18  https://is5-ssl.mzstatic.com/image/thumb/Music...             NaN
# 19  https://is2-ssl.mzstatic.com/image/thumb/Music...            1.29
#
#     collectionExplicitness trackCount  \
# 0              notExplicit         12
# 1              notExplicit         16
# 2              notExplicit         43
# 3              notExplicit          9
# 4              notExplicit         11
# 5              notExplicit         12
# 6              notExplicit          5
# 7              notExplicit         10
# 8              notExplicit         12
# 9              notExplicit         14
# 10             notExplicit         14
# 11             notExplicit          8
# 12             notExplicit         30
# 13             notExplicit         11
# 14                 cleaned          5
# 15             notExplicit         11
# 16             notExplicit          1
# 17             notExplicit          1
# 18             notExplicit        116
# 19                explicit          1
#
#                                             copyright country currency  \
# 0   ℗ 2004 Warner Records Inc. Manufactured and Ma...     USA      USD
# 1                   ℗ 2005 Warner Strategic Marketing     USA      USD
# 2   ℗ 2005 Atlantic Recording Corp. Manufactured &...     USA      USD
# 3   ℗ 2004 Atlantic Recording Corp. Manufactured &...     USA      USD
# 4   ℗ 2004 Atlantic Recording Corp. Manufactured &...     USA      USD
# 5                   ℗ 2004 Warner Strategic Marketing     USA      USD
# 6              ℗ 2005 Warner Strategic Marketing Inc.     USA      USD
# 7   ℗ 2004 Warner Records Inc. Manufactured & Mark...     USA      USD
# 8   ℗ 2005 Warner Records Inc. Manufactured and Ma...     USA      USD
# 9   ℗ 2005 Warner Records Inc. Manufactured & Mark...     USA      USD
# 10  ℗ 2004 Atlantic Recording Corp. Manufactured &...     USA      USD
# 11  ℗ 2004 Atlantic Recording Corp. Manufactured &...     USA      USD
# 12         ℗ 2016 Warner Music Group - X5 Music Group     USA      USD
# 13  ℗ 2004 Warner Records Inc. Manufactured and Ma...     USA      USD
# 14                              ℗ 1976 REG Associates     USA      USD
# 15         ℗ 2020 Warner Music Group - X5 Music Group     USA      USD
# 16                               ℗ 2022 Rez'Arts Prod     USA      USD
# 17                                  ℗ 2020 The Meters     USA      USD
# 18         ℗ 2020 Warner Music Group - X5 Music Group     USA      USD
# 19                               ℗ 2022 Rez'Arts Prod     USA      USD
#
#              releaseDate primaryGenreName contentAdvisoryRating
# 0   2005-02-08T08:00:00Z         R&B/Soul                   NaN
# 1   2005-03-29T08:00:00Z         R&B/Soul                   NaN
# 2   2005-03-29T08:00:00Z         R&B/Soul                   NaN
# 3   2005-02-08T08:00:00Z         R&B/Soul                   NaN
# 4   2005-02-08T08:00:00Z         R&B/Soul                   NaN
# 5   2005-02-08T08:00:00Z         R&B/Soul                   NaN
# 6   2005-09-20T07:00:00Z         R&B/Soul                   NaN
# 7   2005-02-08T08:00:00Z         R&B/Soul                   NaN
# 8   2005-03-29T08:00:00Z         R&B/Soul                   NaN
# 9   2005-09-20T07:00:00Z         R&B/Soul                   NaN
# 10  2005-02-08T08:00:00Z         R&B/Soul                   NaN
# 11  2005-02-08T08:00:00Z         R&B/Soul                   NaN
# 12  2016-12-22T08:00:00Z              Pop                   NaN
# 13  2005-02-08T08:00:00Z         R&B/Soul                   NaN
# 14  1976-12-01T08:00:00Z         R&B/Soul                 Clean
# 15  2020-09-11T07:00:00Z         R&B/Soul                   NaN
# 16  2022-02-10T08:00:00Z      Alternative                   NaN
# 17  2020-10-02T07:00:00Z             Rock                   NaN
# 18  2020-04-03T07:00:00Z         R&B/Soul                   NaN
# 19  2022-02-10T08:00:00Z      Alternative              Explicit
#
# [20 rows x 21 columns]

# %% [markdown]
# ## Using Beautiful Soup to Parse a Webpage.
#
# The [beautifulsoup4 documentation](https://www.crummy.com/software/BeautifulSoup/).

# %%
# Grab the course webpage.
import requests
from bs4 import BeautifulSoup

r = requests.get('https://cs.tulane.edu/~aculotta/')

soup = BeautifulSoup( r.content )

# %%
r.content[:5000]
# Out:
# b'<html>\n\t<head>\n\t\t<link rel="stylesheet" href="style.css">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1">\n\t</head>\n\t<body>\n\t\t<div class="main">\n\t\t\taron culotta  &nbsp;&nbsp;&nbsp;&nbsp;  &nbsp; <br>associate professor of computer science<br>tulane university<br>\n\t\t\t<script type="text/javascript" language="javascript"> // Email obfuscator script 2.1 by Tim Williams, University of Arizona\n\t\t\t{ coded = "LzVZhppL@pVZLJW.WlV"\n  \t\t\t\tkey = "fID9HXVvy5dwPqtn0FjROcgms4kr1l7xKpJeaSQ3zoA8NUEYZubiMBWLTGC6h2"\n\t  \t\t\tshift=coded.length\n\t\t\t\t  link=""\n\t\t\t\t  for (i=0; i<coded.length; i++) {\n\t\t\t\t    if (key.indexOf(coded.charAt(i))==-1) {\n\t\t\t\t      ltr = coded.charAt(i)\n\t\t\t\t      link += (ltr)\n\t\t\t\t    }\n\t\t\t\t    else { \n\t\t\t\t      ltr = (key.indexOf(coded.charAt(i))-shift+key.length) % key.length\n\t\t\t\t      link += (key.charAt(ltr))\n\t\t\t\t    }\n\t\t\t\t  }\n\t\t\t\tdocument.write(link)\n\t\t\t\t}\n\t\t\t\t//-->\n\t\t\t</script>\n\t\t\t<noscript>Sorry, you need Javascript on to email me.</noscript>\n\t\t\t<br>\n\t\t\t<font size=+2>\n\t\t\t<a href="cv.pdf">cv</a> &nbsp; <a href="http://scholar.google.com/citations?user=481oUzkAAAAJ">scholar</a> &nbsp; <a href="#teaching">teaching</a> &nbsp; <a href="#funding">funding</a> &nbsp; <a href="#awards">awards</a> &nbsp; <a href="#publications">pubs</a></font>\n\t\t\t<br><br><br>\n\n\n\t\t\tI investigate computational methods to discover socially-beneficial knowledge from text and social networks.\n\t\t\tExamples include <a href="http://cs.tulane.edu/~aculotta/pubs/culotta13lightweight.pdf">tracking</a> <a href="http://cs.tulane.edu/~aculotta/pubs/culotta10detecting.pdf">diseases</a>, measuring effectiveness of <a href="http://cs.tulane.edu/~aculotta/pubs/culotta16towards.pdf">public health</a> campaigns, <a href="http://cs.tulane.edu/~aculotta/pubs/ashktorab14tweedr.pdf">informing</a> crisis <a href="http://cs.tulane.edu/~aculotta/pubs/mandel12demo.pdf">response</a>, <a href="http://cs.tulane.edu/~aculotta/pubs/liu2018forecasting.pdf">preventing online harassment</a>, <a href="http://cs.tulane.edu/~aculotta/pubs/wang17words.pdf">detecting deceptive marketing</a>, and <a href="http://cs.tulane.edu/~aculotta/pubs/bhat17identifying.pdf">identifying unsafe products</a>.\n\t\t    </p>\n\t\t\t\n\t\t\t\n\t\t\t<p>\n\t\t\tThe methods rely on machine learning, natural language processing, and social network analysis. Areas of technical contribution include <a href="http://cs.tulane.edu/~aculotta/pubs/landeiro19discovering.pdf">domain adaptation</a>, <a href="http://cs.tulane.edu/~aculotta/pubs/ehsan17training.pdf">learning from label proportions</a>, and <a href="http://cs.tulane.edu/~aculotta/pubs/wang19when.pdf">causal inference</a>.\n\t\t\t <!-- See our <a href="http://tapilab.github.io/">lab page</a> for more. -->\n\t\t\t</p>\n\t\t\t\n\n \t\t\t<p>\n\t\t\tI also lead the <a href="https://tulanecs.github.io/tuceai/">Tulane Center for Community-Engaged Artificial Intelligence</a> and the <a href="https://ai.tulane.edu/">Jurist Center for Artificial Intelligence</a>.\n\t\t\t</p>\n\n\t\t\t<p>\n\t\t\t<br>\n\t\t\tAre you a student interested in a <a href="https://goo.gl/forms/XCJAwpzva0DE7Pol1">phd</a> or <a href="https://goo.gl/forms/3vEGOWcMcS79kALj1">independent study</a>?\n\t\t\t</p>\n\n\t\t\t<br><br>\n\n\t\t\t<a name="teaching"><span class=\'bold\'>teaching</span></a>\n\t\t\t<br><br>\n\t\t\t<table class="teaching" border=0>\n\t\t\t\t<tr>\n\t\t\t\t\t<td>&nbsp;&nbsp;&nbsp;&nbsp;</td>\n\t\t\t\t\t<td>tulane</td>\n\t\t\t\t\t<td>&nbsp;&nbsp;&nbsp;&nbsp;</td>\n\t\t\t\t\t<td><a href="https://github.com/tulane-cmps6730/main">natural language processing</a>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>\n\t\t\t\t\t<td><a href="https://github.com/tulane-cmps2200/slides/tree/2020-fall">intro to algorithms</a></td>\n\t\t\t\t</tr>\n\t\t\t\t<tr>\n\t\t\t\t\t<td>&nbsp;&nbsp;&nbsp;&nbsp;</td>\n\t\t\t\t\t<td>illinois tech</t ...

# %%
soup.prettify()[:5000]
# Out:
# '<html>\n <head>\n  <link href="style.css" rel="stylesheet"/>\n  <meta content="width=device-width, initial-scale=1" name="viewport"/>\n </head>\n <body>\n  <div class="main">\n   aron culotta\n   <br/>\n   associate professor of computer science\n   <br/>\n   tulane university\n   <br/>\n   <script language="javascript" type="text/javascript">\n    // Email obfuscator script 2.1 by Tim Williams, University of Arizona\n\t\t\t{ coded = "LzVZhppL@pVZLJW.WlV"\n  \t\t\t\tkey = "fID9HXVvy5dwPqtn0FjROcgms4kr1l7xKpJeaSQ3zoA8NUEYZubiMBWLTGC6h2"\n\t  \t\t\tshift=coded.length\n\t\t\t\t  link=""\n\t\t\t\t  for (i=0; i<coded.length; i++) {\n\t\t\t\t    if (key.indexOf(coded.charAt(i))==-1) {\n\t\t\t\t      ltr = coded.charAt(i)\n\t\t\t\t      link += (ltr)\n\t\t\t\t    }\n\t\t\t\t    else { \n\t\t\t\t      ltr = (key.indexOf(coded.charAt(i))-shift+key.length) % key.length\n\t\t\t\t      link += (key.charAt(ltr))\n\t\t\t\t    }\n\t\t\t\t  }\n\t\t\t\tdocument.write(link)\n\t\t\t\t}\n\t\t\t\t//-->\n   </script>\n   <noscript>\n    Sorry, you need Javascript on to email me.\n   </noscript>\n   <br/>\n   <font size="+2">\n    <a href="cv.pdf">\n     cv\n    </a>\n    <a href="http://scholar.google.com/citations?user=481oUzkAAAAJ">\n     scholar\n    </a>\n    <a href="#teaching">\n     teaching\n    </a>\n    <a href="#funding">\n     funding\n    </a>\n    <a href="#awards">\n     awards\n    </a>\n    <a href="#publications">\n     pubs\n    </a>\n   </font>\n   <br/>\n   <br/>\n   <br/>\n   I investigate computational methods to discover socially-beneficial knowledge from text and social networks.\n\t\t\tExamples include\n   <a href="http://cs.tulane.edu/~aculotta/pubs/culotta13lightweight.pdf">\n    tracking\n   </a>\n   <a href="http://cs.tulane.edu/~aculotta/pubs/culotta10detecting.pdf">\n    diseases\n   </a>\n   , measuring effectiveness of\n   <a href="http://cs.tulane.edu/~aculotta/pubs/culotta16towards.pdf">\n    public health\n   </a>\n   campaigns,\n   <a href="http://cs.tulane.edu/~aculotta/pubs/ashktorab14tweedr.pdf">\n    informing\n   </a>\n   crisis\n   <a href="http://cs.tulane.edu/~aculotta/pubs/mandel12demo.pdf">\n    response\n   </a>\n   ,\n   <a href="http://cs.tulane.edu/~aculotta/pubs/liu2018forecasting.pdf">\n    preventing online harassment\n   </a>\n   ,\n   <a href="http://cs.tulane.edu/~aculotta/pubs/wang17words.pdf">\n    detecting deceptive marketing\n   </a>\n   , and\n   <a href="http://cs.tulane.edu/~aculotta/pubs/bhat17identifying.pdf">\n    identifying unsafe products\n   </a>\n   .\n   <p>\n    The methods rely on machine learning, natural language processing, and social network analysis. Areas of technical contribution include\n    <a href="http://cs.tulane.edu/~aculotta/pubs/landeiro19discovering.pdf">\n     domain adaptation\n    </a>\n    ,\n    <a href="http://cs.tulane.edu/~aculotta/pubs/ehsan17training.pdf">\n     learning from label proportions\n    </a>\n    , and\n    <a href="http://cs.tulane.edu/~aculotta/pubs/wang19when.pdf">\n     causal inference\n    </a>\n    .\n    <!-- See our <a href="http://tapilab.github.io/">lab page</a> for more. -->\n   </p>\n   <p>\n    I also lead the\n    <a href="https://tulanecs.github.io/tuceai/">\n     Tulane Center for Community-Engaged Artificial Intelligence\n    </a>\n    and the\n    <a href="https://ai.tulane.edu/">\n     Jurist Center for Artificial Intelligence\n    </a>\n    .\n   </p>\n   <p>\n    <br/>\n    Are you a student interested in a\n    <a href="https://goo.gl/forms/XCJAwpzva0DE7Pol1">\n     phd\n    </a>\n    or\n    <a href="https://goo.gl/forms/3vEGOWcMcS79kALj1">\n     independent study\n    </a>\n    ?\n   </p>\n   <br/>\n   <br/>\n   <a name="teaching">\n    <span class="bold">\n     teaching\n    </span>\n   </a>\n   <br/>\n   <br/>\n   <table border="0" class="teaching">\n    <tr>\n     <td>\n     </td>\n     <td>\n      tulane\n     </td>\n     <td>\n     </td>\n     <td>\n      <a href="https://github.com/tulane-cmps6730/main"> ...

# %%
soup.find("table")
# Out:
# <table border="0" class="teaching">
# <tr>
# <td>    </td>
# <td>tulane</td>
# <td>    </td>
# <td><a href="https://github.com/tulane-cmps6730/main">natural language processing</a>       </td>
# <td><a href="https://github.com/tulane-cmps2200/slides/tree/2020-fall">intro to algorithms</a></td>
# </tr>
# <tr>
# <td>    </td>
# <td>illinois tech</td>
# <td>    </td>
# <td><a href="https://github.com/iit-cs579/main">online social network analysis</a></td>
# <td><a href="https://github.com/iit-cs429/main">information retrieval</a></td>
# </tr>
# </table>

# %%
# The above gets the first table, but there could be a lot more!
soup.findAll("table")

# %%
# Find all links!

soup.find("table").findAll("a")
# Out:
# [<a href="https://github.com/tulane-cmps6730/main">natural language processing</a>,
#  <a href="https://github.com/tulane-cmps2200/slides/tree/2020-fall">intro to algorithms</a>,
#  <a href="https://github.com/iit-cs579/main">online social network analysis</a>,
#  <a href="https://github.com/iit-cs429/main">information retrieval</a>]

# %% [markdown]
# So we can use Pandas and BS4 together as well -- we'll see a lot more of this in the lab this week!

# %%
df_tables = []
for t in soup.findAll("table"):
    df_t = pd.read_html(str(t))
    df_tables.append(df_t[0])

for t in df_tables:
    display(t)
# Out:
#     0              1   2                               3  \
# 0 NaN         tulane NaN     natural language processing
# 1 NaN  illinois tech NaN  online social network analysis
#
#                        4
# 0    intro to algorithms
# 1  information retrieval
#                                                     0
# 0   Online Reviews Are Leading Indicators of Chang...
# 1   Forecasting COVID-19 Vaccination Rates using S...
# 2   Safety Reviews on Airbnb: An Information Tale ...
# 3   Reducing Cross-Topic Political Homogenization ...
# 4   Identifying Hurricane Evacuation Intent on Twi...
# ..                                                ...
# 72  Dependency tree kernels for relation extractio...
# 73  Interactive information extraction with constr...
# 74  Confidence estimation for information extracti...
# 75  Extracting social networks and contact informa...
# 76  Maximizing cascades in social networks Aron Cu...
#
# [77 rows x 1 columns]

# %% [markdown]
# ## Trying out some Regular Expressions.

# %%
import re
# Find the index in the raw HTML where we first mention CMPS3160

# Note we use the r to make sure special flags get used correctly.

r = requests.get('https://nmattei.github.io/cmps3160/syllabus/')

# %%
# Let's see what we got.
r.text[:5000]
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n  <!-- Beautiful Jekyll | MIT license | Copyright Dean Attali 2016 -->\n  <head>\n  <meta charset="utf-8" />\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, viewport-fit=cover">\n\n  <title>Fall 2022 Syllabus</title>\n\n  <meta name="author" content="Nicholas Mattei" />\n\n  \n\n  <link rel="alternate" type="application/rss+xml" title="CMPS 3160 Intro. to Data Science - Intro to Data Science - Fall 2020" href="https://nmattei.github.io/cmps3160/feed.xml" />\n\n  \n\n  \n\n  \n\n\n  \n    \n      \n  <link rel="stylesheet" href="//maxcdn.bootstrapcdn.com/font-awesome/4.6.0/css/font-awesome.min.css" />\n\n\n    \n  \n\n  \n    \n      <link rel="stylesheet" href="/cmps3160/css/bootstrap.min.css" />\n    \n      <link rel="stylesheet" href="/cmps3160/css/bootstrap-social.css" />\n    \n      <link rel="stylesheet" href="/cmps3160/css/main.css" />\n    \n  \n\n  \n    \n      <link rel="stylesheet" href="//fonts.googleapis.com/css?family=Lora:400,700,400italic,700italic" />\n    \n      <link rel="stylesheet" href="//fonts.googleapis.com/css?family=Open+Sans:300italic,400italic,600italic,700italic,800italic,400,300,600,700,800" />\n    \n  \n\n  \n\n  \n\n  \n\n    <!-- Facebook OpenGraph tags -->\n  \n\n  \n  <meta property="og:title" content="Fall 2022 Syllabus" />\n  \n\n   \n  <meta property="og:description" content="# Introduction to Data Science * CMPS-3160/3160-01/02: Introduction to Data Science Fall 2022 * Tulane University * 3 Credit Hours * Prerequisite Courses: CMPS 1100 Foundations of Programming or CMPS 1500 Intro to Computer Science I, or consent of instructor. ## Common Information for Both Sections Note that there are...">\n  \n\n\n  <meta property="og:type" content="website" />\n\n  \n  <meta property="og:url" content="https://nmattei.github.io/cmps3160/syllabus/" />\n  <link rel="canonical" href="https://nmattei.github.io/cmps3160/syllabus/" />\n  \n\n  \n\n\n  <!-- Twitter summary cards -->\n  <meta name="twitter:card" content="summary" />\n  <meta name="twitter:site" content="@" />\n  <meta name="twitter:creator" content="@" />\n\n  \n  <meta name="twitter:title" content="Fall 2022 Syllabus" />\n  \n\n  \n  <meta name="twitter:description" content="# Introduction to Data Science * CMPS-3160/3160-01/02: Introduction to Data Science Fall 2022 * Tulane University * 3 Credit Hours * Prerequisite Courses: CMPS 1100 Foundations of Programming or CMPS 1500 Intro to Computer Science I, or consent of instructor. ## Common Information for Both Sections Note that there are...">\n  \n\n  \n\n  \n\n  \n\n</head>\n\n\n  <body>\n\n    \n\n  \n    <nav class="navbar navbar-default navbar-fixed-top navbar-custom">\n  <div class="container-fluid">\n    <div class="navbar-header">\n      <button type="button" class="navbar-toggle" data-toggle="collapse" data-target="#main-navbar">\n        <span class="sr-only">Toggle navigation</span>\n        <span class="icon-bar"></span>\n        <span class="icon-bar"></span>\n        <span class="icon-bar"></span>\n      </button><a class="navbar-brand" href="https://nmattei.github.io/cmps3160">CMPS 3160 Intro. to Data Science</a></div>\n\n    <div class="collapse navbar-collapse" id="main-navbar">\n      <ul class="nav navbar-nav navbar-right">\n          <li><a href="/cmps3160/syllabus">Syllabus</a></li>\n          <li><a href="/cmps3160/schedule">Schedule and Assignments</a></li>\n          <li><a href="/cmps3160/projects/FinalTutorial">Final Tutorial</a></li>\n          <li><a href="/cmps3160/resources">Links & Resources</a></li></ul>\n    </div>\n\n\t\n\n  </div>\n</nav>\n\n\n    <!-- TODO this file has become a mess, refactor it -->\n\n\n\n\n\n<header class="header-section ">\n\n<div class="intro-header no-img">\n  <div class="container">\n    <div class="row">\n      <div class="col-lg-8 col-lg-offset-2 col-md-10 col-md-offset-1">\n        <div cla ...

# %%
match = re.search(r'CMPS 3160', r.text)
print(match.start())
# Out:
# 460

# %%
r.text[390:500]
# Out:
# 'ei" />\n\n  \n\n  <link rel="alternate" type="application/rss+xml" title="CMPS 3160 Intro. to Data Science - Intro'

# %%
# Does the start match?
match = re.match(r'CMPS 3160', r.text)
print(match)
# Out:
# None

# %%
# Iterate over all occurances and print a few characters.
for m in re.finditer(r'CMPS 3160', r.text):
    print(r.text[m.start()-50:m.start()+50])
# Out:
# rel="alternate" type="application/rss+xml" title="CMPS 3160 Intro. to Data Science - Intro to Data S
# -brand" href="https://nmattei.github.io/cmps3160">CMPS 3160 Intro. to Data Science</a></div>
#
#     <d
# the <a href="https://github.com/nmattei/cmps3160">CMPS 3160 Github</a>.</p>
#   </li>
#   <li>
#     <p>Al

# %%
# Find them all and the word(s)? right after?
match = re.findall(r'CMPS 3160\s\w*', r.text)
print(match)
# Out:
# ['CMPS 3160 Intro', 'CMPS 3160 Intro', 'CMPS 3160 Github']

# %%
# Can we find all the email addresses?
text = ''' This is a list that has an @ symbol in it.
            But we want to find Nick's address nsmattei@tulane.edu
            But also maybe someone else's eli@gmail.com....
            How would we write a regex for that?


            Also there is more text, and can't like
            phil123@school.edu also be able to be caught?



'''

# Need to test on a few first..
# What rules do we need?
regex = r'\D\w*@\w+\.\w{3}'
match = re.findall(regex, text)
print(match)
# Out:
# [' nsmattei@tulane.edu', ' eli@gmail.com', ' phil123@school.edu']

# %%
### ANSWER for full email
regex = r'\w+@\w+.\w{3}'
match = re.findall(regex, text)
print(match)
# Out:
# ['nsmattei@tulane.edu', 'eli@gmail.com', 'phil123@school.edu']

# %%
### Only names, no domains...
regex = r'\w+@'
match = re.findall(regex, text)
print(match)
# Out:
# ['nsmattei@', 'eli@', 'phil123@']

# %%
## Eli's more complicated answer with lookaheads
regex = r"[A-z]+(?=[^A-z\s]*@)"
match = re.findall(regex, text)
print(match)
# Out:
# ['nsmattei', 'eli', 'phil']

# %%
# Now we can use this on the webpage!
regex = r'\w+@\w+.\w{3}'
match = re.findall(regex, r.text)
print(match)
# Out:
# ['kshvaram@tulane.edu', 'kshvaram@tulane.edu', 'skellum@tulane.edu', 'skellum@tulane.edu', 'nsmattei@tulane.edu', 'nsmattei@tulane.edu', 'aculotta@tulane.edu', 'aculotta@tulane.edu', 'goldman@tulane.edu', 'srss@tulane.edu', 'srss@tulane.edu', 'msmith76@tulane.edu', 'msmith76@tulane.edu']

# %%
# More complicated RegExes - Groups
regex = r'\s*([Uu]niversity)\s([Oo]f)\s(\w{3,})'

text = ''' The university of kentucky is the best
            basketball team and an ok university. and University of North CC
            The University Of Kentucky can be put in
            some weird capitalization and University of Ken spelled wrong'''
m = re.search( regex, text)
print(m.groups())
# Out:
# ('university', 'of', 'kentucky')

# %%
# Find all
print(re.findall(regex, text))
# Out:
# [('university', 'of', 'kentucky'), ('University', 'of', 'North'), ('University', 'Of', 'Kentucky'), ('University', 'of', 'Ken')]

# %%
# Named Groups.
regex = r'\s*([Uu]niversity)\s([Oo]f)\s(?P<school>\w{3,})'
text = ''' The university of kentucky is the best University of Lousiana
            basketball team and an ok university.
            The University Of Kentucky can be put in
            some weird capitalization'''
m = re.search( regex, text)
print(m.groupdict())
# Out:
# {'school': 'kentucky'}

# %%
# Find all named groups

# Named Groups.
regex = r'\s*([Uu]niversity)\s([Oo]f)\s(?P<school>\w{3,})'
text = ''' The university of kentucky is the best
            basketball team and an ok university.
            The University Of Kentucky can be put in
            some weird capitalization.  And Kentucky is much better than
            the University of Mississippi.'''
for m in re.finditer(regex, text):
    print(m.groupdict())
# Out:
# {'school': 'kentucky'}
# {'school': 'Kentucky'}
# {'school': 'Mississippi'}

# %%
'abcabcabc'.replace('a', 'X')
# Out:
# 'XbcXbcXbc'

# %%
text = 'I love Introduction to Data Science'
re.sub(r'Data Science', r'Schmada Schmience', text)
# Out:
# 'I love Introduction to Schmada Schmience'

# %%
re.sub(r'(\w+)\s([Ss]cience)', r'\2 \1hmience', text)
# Out:
# 'I love Introduction to Science Datahmience'

# %%
# Let's use it to parse part of a CSV?
text = '12,15,22,36,78,33,77,33,45'

# Use Regex split command
print(re.split(',', text))

# Use string split command
print(text.split(","))

#Use Regex to split into groups...
regex = r'(?P<data>\d*,)'
for m in re.finditer(regex, text):
    print(m.groupdict())
# Out:
# ['12', '15', '22', '36', '78', '33', '77', '33', '45']
# ['12', '15', '22', '36', '78', '33', '77', '33', '45']
# {'data': '12,'}
# {'data': '15,'}
# {'data': '22,'}
# {'data': '36,'}
# {'data': '78,'}
# {'data': '33,'}
# {'data': '77,'}
# {'data': '33,'}
